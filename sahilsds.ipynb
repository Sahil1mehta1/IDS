# %%
import pandas as pd #import data by using libarary.
import seaborn as sns
import matplotlib.pyplot as plt
sahil=pd.read_csv(r"C:\Users\sm843\Downloads\AB_NYC_2019.csv") 
sahil
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sahil.head(10)# shows first 10 columns
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
sahil.tail(10)# shows last 10 columns
# Out:
#              id                                               name    host_id  \
# 48885  36482809    Stunning Bedroom NYC! Walking to Central Park!!  131529729
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
sahil.describe() # desscribe the data in dataset in form  of count,mean,deviation etc.
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
sahil.info() # gives information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# room_type_counts = sahil['room_type'].value_counts()
#
# plt.figure(figsize=(6, 6))
# plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%', startangle=140)
# plt.title('Room Type Distribution')
# plt.show()

# %%
sahil.describe # describe the data
# Out:
# <bound method NDFrame.describe of              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sns.histplot(sahil['minimum_nights'], kde=True).set_title('Minimum Nights Distribution')#univariate analysis :numerically
plt.show()

# %%
sns.histplot(sahil['reviews_per_month'], kde=True).set_title('review Distribution') #univariate analysis :numerically
plt.show()

# %%
sns.countplot(x='neighbourhood_group', data=sahil).set_title('neighbour group Count') #Univariate Analysis: Categorical
plt.show()

# %%
neighbourhood_counts = sahil['neighbourhood_group'].value_counts()#univariate piechart dostribution of neighbourhood.
plt.figure(figsize=(6, 6))
plt.pie(neighbourhood_counts, labels=neighbourhood_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Neighbourhood Group Distribution')
plt.show()

# %%
sns.countplot(x='reviews_per_month',data=sahil).set_title('neighbour distribution')#univariate analysis categorically of reviews per month.
plt.show()

# %%
room_type_counts = sahil['room_type'].value_counts()#univariate pie chart distribution of room type.
plt.figure(figsize=(6, 6))
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Room Type Distribution')
plt.show()

# %%
sns.countplot(x='room_type', data=sahil).set_title('room Distribution')#unnivariate analysis of room distribution
plt.show()

# %%
sns.scatterplot(x='minimum_nights', y='price', hue='room_type', data=sahil)#scatter plot of minimun nights V/S price colored by room type
plt.title('Minimum Nights vs Price Colored by Room Type')
plt.xlabel('Minimum nights')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
sns.scatterplot(x='number_of_reviews',y='price',hue='neighbourhood_group',data=sahil,alpha=0.7)#scatter plot of reviews and price
plt.title('Number of Reviews vs Price Colored by Neighbourhood Group')
plt.xlabel('Number of Reviews')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))#scatter plot of reviews and aavailability.
plt.scatter(sahil['availability_365'], sahil['number_of_reviews'], color='teal', alpha=0.5)
plt.title('Availability vs Number of Reviews')
plt.xlabel('Availability (days/year)')
plt.ylabel('Number of Reviews')
plt.grid(True)
plt.show()

# %%
sns.scatterplot(x='price', y='minimum_nights', hue='room_type', data=sahil)# scatter plot of price and min.nights
plt.title('Price vs Minimum Nights by Room Type')
plt.xlabel('Price')
plt.ylabel('Minimum Nights')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))# scatter plot for price and reviews.
plt.scatter(sahil['price'], sahil['number_of_reviews'], alpha=0.6, c='purple')
plt.title('Price vs Number of Reviews')
plt.xlabel('Price ($)')
plt.ylabel('Number of Reviews')
plt.grid(True)
plt.show()

# %%
sns.countplot(x='room_type', hue='neighbourhood_group', data=sahil)#bivrate analysis for room type.
plt.title('Room Type by Neighbourhood Group')
plt.show()

# %%
sns.boxplot(x='room_type', y='price', hue='room_type', data=sahil)# bivrate analysis for room type V/S price.
plt.title('Price by Room Type')
plt.show()

# %%
sns.boxplot(x='room_type', y='minimum_nights', hue='room_type', data=sahil)#bivrate analysis for room type V/S minimum nights.
plt.title('Minimum Nights by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Minimum Nights')
plt.show()

# %%
sns.scatterplot(x='price', y='availability_365', hue='neighbourhood_group', data=sahil)#scatter plot(bivrate) of price V/S 365
plt.title('Price vs Availability (Colored by Neighbourhood Group)')
plt.xlabel('Price ($)')
plt.ylabel('Availability (Days per Year)')
plt.grid(True)
plt.show()

# %%
manhattan_df = sahil[sahil['neighbourhood_group'] == 'Manhattan']#filter for neighbourhood group.
brooklyn_df = sahil[sahil['neighbourhood_group'] == 'Brooklyn']
manhattan_room_counts = manhattan_df['room_type'].value_counts()#room type counts.
brooklyn_room_counts = brooklyn_df['room_type'].value_counts()
plt.figure(figsize=(6, 6))#plot room type 
plt.pie(manhattan_room_counts, labels=manhattan_room_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Room Type Distribution in Manhattan')
plt.show()
plt.figure(figsize=(6, 6))#plot room type
plt.pie(brooklyn_room_counts, labels=brooklyn_room_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Room Type Distribution in Brooklyn')
plt.show()

# %%
#multivariate analysis with pairplot.
selected_columns = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365']
clean_data = sahil[selected_columns + ['neighbourhood_group']].dropna()
sns.pairplot(clean_data, vars=selected_columns, hue='neighbourhood_group')
plt.suptitle("Pairplot of Selected Features Colored by Neighbourhood Group", y=1.02)
plt.show()

# %%
plt.figure(figsize=(10, 6))# multivariate scatter plot.
sns.scatterplot(x='price',y='minimum_nights',hue='neighbourhood_group',size='availability_365',style='room_type',data=sahil,palette='Set1',sizes=(50, 250),alpha=0.7)
plt.title('Multivariate Scatter Plot: Price vs Minimum Nights')
plt.xlabel('Price ($)')
plt.ylabel('Minimum Nights')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
corr_matrix = sahil.corr(numeric_only=True)#correlation heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap (Airbnb NYC)')
plt.show()
